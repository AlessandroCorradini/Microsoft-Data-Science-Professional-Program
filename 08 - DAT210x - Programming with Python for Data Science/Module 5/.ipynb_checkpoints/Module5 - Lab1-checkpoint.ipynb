# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module5- Lab1

# %% [markdown]
# Start by importing whatever you need to import in order to make this lab work:

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib

from sklearn.cluster import KMeans

# %% [markdown]
# ### How to Get The Dataset

# %% [markdown]
# 1. Open up the City of Chicago's [Open Data | Crimes](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2) page.
# 1. In the `Primary Type` column, click on the `Menu` button next to the info button, and select `Filter This Column`. It might take a second for the filter option to show up, since it has to load the entire list first.
# 1. Scroll down to `GAMBLING`
# 1. Click the light blue `Export` button next to the `Filter` button, and select `Download As CSV`

# %% [markdown]
# Now that you have th dataset stored as a CSV, load it up being careful to double check headers, as per usual:

# %%
df = pd.read_csv('Datasets/Crimes_-_2001_to_present.csv')
df.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  10002677    HY191890  03/20/2015 01:13:00 PM       020XX W 70TH ST  1661
# 1  10003802    HY193541  03/21/2015 06:45:00 PM     042XX W MONROE ST  1661
# 2  10003937    HY193663  03/21/2015 07:55:00 PM  032XX W LAWRENCE AVE  1670
# 3  10004429    HY194332  03/22/2015 01:57:00 PM  019XX S ST LOUIS AVE  1661
# 4  10005837    HY195964  03/23/2015 08:40:00 PM     039XX W CERMAK RD  1661
#
#   Primary Type            Description            Location Description  Arrest  \
# 0     GAMBLING              GAME/DICE                          STREET    True
# 1     GAMBLING              GAME/DICE                        SIDEWALK    True
# 2     GAMBLING  GAME/AMUSEMENT DEVICE              SMALL RETAIL STORE    True
# 3     GAMBLING              GAME/DICE                        SIDEWALK    True
# 4     GAMBLING              GAME/DICE  PARKING LOT/GARAGE(NON.RESID.)    True
#
#    Domestic              ...                Ward  Community Area  FBI Code  \
# 0     False              ...                17.0            67.0        19
# 1     False              ...                28.0            26.0        19
# 2     False              ...                39.0            14.0        19
# 3     False              ...                24.0            29.0        19
# 4     False              ...                24.0            29.0        19
#
#    X Coordinate  Y Coordinate  Year              Updated On   Latitude  \
# 0     1164027.0     1858234.0  2015  02/10/2018 03:50:01 PM  41.766615
# 1     1148136.0     1899324.0  2015  02/10/2018 03:50:01 PM  41.879691
# 2     1154071.0     1931710.0  2015  02/10/2018 03:50:01 PM  41.968445
# 3     1153407.0     1890195.0  2015  02/10/2018 03:50:01 PM  41.854537
# 4     1150290.0     1889088.0  2015  02/10/2018 03:50:01 PM  41.851561
#
#    Longitude                       Location
# 0 -87.674337  (41.766615006, -87.674337321)
# 1 -87.731530  (41.879691121, -87.731529667)
# 2 -87.708871  (41.968444682, -87.708871059)
# 3 -87.712418   (41.854537081, -87.71241763)
# 4 -87.723887  (41.851560618, -87.723887245)
#
# [5 rows x 22 columns]

# %% [markdown]
# Get rid of any _rows_ that have nans in them:

# %%
df.isnull().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       0
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                    1124
# Community Area          1124
# FBI Code                   0
# X Coordinate              98
# Y Coordinate              98
# Year                       0
# Updated On                 0
# Latitude                  98
# Longitude                 98
# Location                  98
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %% [markdown]
# Display the `dtypes` of your dset:

# %%
df.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                      int64
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                  int64
# Ward                    float64
# Community Area          float64
# FBI Code                  int64
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %% [markdown]
# Coerce the `Date` feature (which is currently a string object) into real date, and confirm by displaying the `dtypes` again. This might be a slow executing process...

# %%
df.Date = pd.to_datetime(df.Date, errors='coerce')

# %%
df.dtypes
# Out:
# ID                               int64
# Case Number                     object
# Date                    datetime64[ns]
# Block                           object
# IUCR                             int64
# Primary Type                    object
# Description                     object
# Location Description            object
# Arrest                            bool
# Domestic                          bool
# Beat                             int64
# District                         int64
# Ward                           float64
# Community Area                 float64
# FBI Code                         int64
# X Coordinate                   float64
# Y Coordinate                   float64
# Year                             int64
# Updated On                      object
# Latitude                       float64
# Longitude                      float64
# Location                        object
# dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(df.Longitude, df.Latitude, marker='.', alpha=0.3)


model = KMeans(n_clusters=7)
model.fit(df[['Longitude', 'Latitude']])
    
centroids = model.cluster_centers_
print(centroids)
ax.scatter(centroids[:,0], centroids[:,1], marker='x', c='red', alpha=0.5, linewidths=3, s=169)
# Out:
# [[-87.70959266  41.87812757]
#  [-87.619313    41.80271357]
#  [-87.66483806  41.77274454]
#  [-87.68545162  41.98129611]
#  [-87.63108338  41.69664745]
#  [-87.75695134  41.89330994]
#  [-87.58210414  41.75210768]]

# %%
def doKMeans(df):
    # Let's plot your data with a '.' marker, a 0.3 alpha at the Longitude,
    # and Latitude locations in your dataset. Longitude = x, Latitude = y
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.scatter(df.Longitude, df.Latitude, marker='.', alpha=0.3)

    
    # TODO: Filter `df` using indexing so it only contains Longitude and Latitude,
    # since the remaining columns aren't really applicable for this lab:
    #
    # .. your code here ..


    # TODO: Use K-Means to try and find seven cluster centers in this df.
    # Be sure to name your kmeans model `model` so that the printing works.
    #
    # .. your code here ..
    model = KMeans(n_clusters=7)
    model.fit(df[['Longitude', 'Latitude']])
    

    # Now we can print and plot the centroids:
    centroids = model.cluster_centers_
    print(centroids)
    ax.scatter(centroids[:,0], centroids[:,1], marker='x', c='red', alpha=0.5, linewidths=3, s=169)

# %%
# Print & Plot your data
doKMeans(df)
# Out:
# [[-87.75688178  41.89341893]
#  [-87.66467914  41.77268635]
#  [-87.70961079  41.87812012]
#  [-87.58260863  41.75260535]
#  [-87.68506657  41.98175614]
#  [-87.61952558  41.80347853]
#  [-87.63102208  41.69651458]]

# %% [markdown]
# Filter out the data so that it only contains samples that have a `Date > '2011-01-01'`, using indexing. Then, in a new figure, plot the crime incidents, as well as a new K-Means run's centroids.

# %%
df2 = df[df.Date > '2011-01-01']
df2
# Out:
#             ID Case Number                Date                      Block  \
# 0     10002677    HY191890 2015-03-20 13:13:00            020XX W 70TH ST
# 1     10003802    HY193541 2015-03-21 18:45:00          042XX W MONROE ST
# 2     10003937    HY193663 2015-03-21 19:55:00       032XX W LAWRENCE AVE
# 3     10004429    HY194332 2015-03-22 13:57:00       019XX S ST LOUIS AVE
# 4     10005837    HY195964 2015-03-23 20:40:00          039XX W CERMAK RD
# 5     10011726    HY200956 2015-03-27 09:10:00         032XX N HARLEM AVE
# 6     10012328    HY201988 2015-03-28 18:45:00    005XX N SPRINGFIELD AVE
# 7     10014339    HY203868 2015-03-30 14:19:00       038XX W ROOSEVELT RD
# 8     10016050    HY205430 2015-03-31 19:05:00      060XX S PRINCETON AVE
# 9     10017499    HY206880 2015-04-01 20:00:00         048XX W GLADYS AVE
# 10    10017527    HY206917 2015-04-01 20:26:00     065XX S MARSHFIELD AVE
# 11    10019991    HY209099 2015-04-03 14:40:00            007XX W 54TH PL
# 12    10021717    HY211521 2015-04-05 18:15:00          043XX W WILCOX ST
# 13    10021787    HY211542 2015-04-05 18:10:00       080XX S ELIZABETH ST
# 14    10021905    HY211720 2015-04-05 21:12:00     072XX S SOUTH SHORE DR
# 15    10022799    HY212450 2015-04-06 15:15:00         051XX W MADISON ST
# 16    10022987    HY212632 2015-04-06 17:19:00        057XX S CALUMET AVE
# 17    10023151    HY212920 2015-04-06 20:06:00           052XX S GREEN ST
# 18    10025150    HY214606 2015-04-08 14:18:00             067XX S MAY ST
# 8718  11157182    JA522352 2017-11-23 00:27:00      095XX S LAFAYETTE AVE
# 8814  11200717    JB111388 2018-01-06 23:07:00          022XX W DEVON AVE
#
#       IUCR Primary Type            Description  \
# 0     1661     GAMBLING              GAME/DICE
# 1     1661     GAMBLING              GAME/DICE
# 2     1670     GAMBLING  GAME/AMUSEMENT DEVICE
# 3     1661     GAMBLING              GAME/DICE
# 4     1661     GAMBLING              GAME/DICE
# 5     1670     GAMBLING  GAME/AMUSEMENT DEVICE
# 6     1661     GAMBLING              GAME/DICE
# 7     1661     GAMBLING              GAME/DICE
# 8     1661     GAMBLING              GAME/DICE
# 9     1661     GAMBLING              GAME/DICE
# 10    1661     GAMBLING              GAME/DICE
# 11    1661     GAMBLING              GAME/DICE
# 12    1661     GAMBLING              GAME/DICE
# 13    1661     GAMBLING              GAME/DICE
# 14    1661     GAMBLING              GAME/DICE
# 15    1661     GAMBLING              GAME/DICE
# 16    1661     GAMBLING              GAME/DICE
# 17    1661     GAMBLING              GAME/DICE
# 18    1661     GAMBLING              GAME/DICE
# 19    1661     GAMBLING              GAME/DICE
# 20    1661     GAMBLING              GAME/DICE
# 21    1661     GAMBLING              GAME/DICE
# 22    1661     GAMBLING              GAME/DICE
# 23    1661     GAMBLING              GAME/DICE
# 24    1661     GAMBLING              GAME/DICE
# 25    1661     GAMBLING              GAME/DICE
# 26    1661     GAMBLING              GAME/DICE
# 27    1661     GAMBLING              GAME/DICE
# 28    1661     GAMBLING              GAME/DICE
# 29    1661     GAMBLING              GAME/DICE
# ...    ...          ...                    ...
# 7186  1661     GAMBLING              GAME/DICE
# 7188  1661     GAMBLING              GAME/DICE
# 7189  1661     GAMBLING              GAME/DICE
# 7190  1661     GAMBLING              GAME/DICE
# 7191  1661     GAMBLING              GAME/DICE
# 7192  1661     GAMBLING              GAME/DICE
# 7193  1661     GAMBLING              GAME/DICE
# 7194  1661     GAMBLING              GAME/DICE
# 7195  1661     GAMBLING              GAME/DICE
# 7196  1661     GAMBLING              GAME/DICE
# 7197  1661     GAMBLING              GAME/DICE
# 7198  1661     GAMBLING              GAME/DICE
# 7199  1661     GAMBLING              GAME/DICE
# 7200  1661     GAMBLING              GAME/DICE
# 7201  1661     GAMBLING              GAME/DICE
# 7915  1661     GAMBLING              GAME/DICE
# 7967  1661     GAMBLING              GAME/DICE
# 7991  1661     GAMBLING              GAME/DICE
# 8219  1680     GAMBLING                  OTHER
# 8220  1661     GAMBLING              GAME/DICE
# 8221  1661     GAMBLING              GAME/DICE
# 8222  1661     GAMBLING              GAME/DICE
# 8223  1661     GAMBLING              GAME/DICE
# 8460  1661     GAMBLING              GAME/DICE
# 8469  1661     GAMBLING              GAME/DICE
# 8491  1661     GAMBLING              GAME/DICE
# 8673  1661     GAMBLING              GAME/DICE
# 8681  1661     GAMBLING              GAME/DICE
# 8718  1661     GAMBLING              GAME/DICE
# 8814  1670     GAMBLING  GAME/AMUSEMENT DEVICE
#
#                 Location Description  Arrest  Domestic  \
# 0                             STREET    True     False
# 1                           SIDEWALK    True     False
# 2                 SMALL RETAIL STORE    True     False
# 3                           SIDEWALK    True     False
# 4     PARKING LOT/GARAGE(NON.RESID.)    True     False
# 5                              OTHER    True     False
# 6                           SIDEWALK    True     False
# 7                           SIDEWALK    True     False
# 8                              ALLEY    True     False
# 9                             STREET    True     False
# 10                             ALLEY    True     False
# 11                          SIDEWALK    True     False
# 12                          SIDEWALK    True     False
# 13                             ALLEY    True     False
# 14           RESIDENCE PORCH/HALLWAY    True     False
# 15                       GAS STATION    True     False
# 16                         RESIDENCE    True     False
# 17                          SIDEWALK    True     False
# 18                          SIDEWALK    True     False
# 19                          SIDEWALK    True     False
# 20                         APARTMENT    True     False
# 21                          SIDEWALK    True     False
# 22    PARKING LOT/GARAGE(NON.RESID.)    True     False
# 23    PARKING LOT/GARAGE(NON.RESID.)    True     False
# 24                          SIDEWALK    True     False
# 25                          SIDEWALK    True     False
# 26                          SIDEWALK    True     False
# 27                          SIDEWALK    True     False
# 28                             OTHER    True     False
# 29                            STREET    True     False
# ...                              ...     ...       ...
# 7186                       APARTMENT    True     False
# 7188                          STREET    True     False
# 7189                        SIDEWALK    True     False
# 7190                        SIDEWALK    True     False
# 7191                        SIDEWALK    True     False
# 7192                        SIDEWALK    True     False
# 7193         CHA PARKING LOT/GROUNDS    True     False
# 7194                        SIDEWALK    True     False
# 7195   RESIDENTIAL YARD (FRONT/BACK)    True     False
# 7196                        SIDEWALK    True     False
# 7197                        SIDEWALK    True     False
# 7198         RESIDENCE PORCH/HALLWAY    True     False
# 7199                   PARK PROPERTY    True     False
# 7200                        SIDEWALK    True     False
# 7201                        SIDEWALK    True     False
# 7915                        SIDEWALK    True     False
# 7967                        SIDEWALK    True     False
# 7991                           ALLEY    True     False
# 8219                      RESTAURANT    True     False
# 8220                        SIDEWALK    True     False
# 8221                        SIDEWALK    True     False
# 8222                        SIDEWALK    True     False
# 8223                       APARTMENT    True     False
# 8460                          STREET    True     False
# 8469                        SIDEWALK    True     False
# 8491   RESIDENTIAL YARD (FRONT/BACK)    True     False
# 8673                        SIDEWALK    True     False
# 8681                        SIDEWALK    True     False
# 8718                        SIDEWALK    True     False
# 8814               CONVENIENCE STORE    True     False
#
#                   ...                Ward  Community Area  FBI Code  \
# 0                 ...                17.0            67.0        19
# 1                 ...                28.0            26.0        19
# 2                 ...                39.0            14.0        19
# 3                 ...                24.0            29.0        19
# 4                 ...                24.0            29.0        19
# 5                 ...                36.0            17.0        19
# 6                 ...                27.0            23.0        19
# 7                 ...                24.0            29.0        19
# 8                 ...                20.0            68.0        19
# 9                 ...                24.0            25.0        19
# 10                ...                15.0            67.0        19
# 11                ...                 3.0            61.0        19
# 12                ...                28.0            26.0        19
# 13                ...                21.0            71.0        19
# 14                ...                 7.0            43.0        19
# 15                ...                28.0            25.0        19
# 16                ...                20.0            40.0        19
# 17                ...                 3.0            61.0        19
# 18                ...                17.0            68.0        19
# 19                ...                17.0            68.0        19
# 20                ...                21.0            71.0        19
# 21                ...                28.0            25.0        19
# 22                ...                24.0            29.0        19
# 23                ...                17.0            68.0        19
# 24                ...                28.0            29.0        19
# 25                ...                28.0            26.0        19
# 26                ...                28.0            27.0        19
# 27                ...                24.0            29.0        19
# 28                ...                15.0            66.0        19
